# %% [raw]
# Kylie Dennison and Blaine Aubrey
# Final Project
# 4/22/26
# CSE-551
#
# In this project, we aim to investigate whether genre influences revenue using real-world data.
# In this project, we aim to investigate whether budget correlates with revenue using real-world data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies=pd.read_csv("tmdb_5000_movies.csv")
credits=pd.read_csv("tmdb_5000_credits.csv")
